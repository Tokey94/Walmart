# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns

# %%
cal = pd.read_csv('/Users/doube/Desktop/calendar.csv')
sellp = pd.read_csv('/Users/doube/Desktop/sell_prices.csv')
stv = pd.read_csv('/Users/doube/Desktop/sales_train_validation.csv')

# %%
sellp
# Out:
#         store_id        item_id  wm_yr_wk  sell_price
# 0           CA_1  HOBBIES_1_001     11325        9.58
# 1           CA_1  HOBBIES_1_001     11326        9.58
# 2           CA_1  HOBBIES_1_001     11327        8.26
# 3           CA_1  HOBBIES_1_001     11328        8.26
# 4           CA_1  HOBBIES_1_001     11329        8.26
# ...          ...            ...       ...         ...
# 6841116     WI_3    FOODS_3_827     11617        1.00
# 6841117     WI_3    FOODS_3_827     11618        1.00
# 6841118     WI_3    FOODS_3_827     11619        1.00
# 6841119     WI_3    FOODS_3_827     11620        1.00
# 6841120     WI_3    FOODS_3_827     11621        1.00
#
# [6841121 rows x 4 columns]

# %%
stv
# Out:
#                                   id        item_id    dept_id   cat_id  \
# 0      HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES
# 1      HOBBIES_1_002_CA_1_validation  HOBBIES_1_002  HOBBIES_1  HOBBIES
# 2      HOBBIES_1_003_CA_1_validation  HOBBIES_1_003  HOBBIES_1  HOBBIES
# 3      HOBBIES_1_004_CA_1_validation  HOBBIES_1_004  HOBBIES_1  HOBBIES
# 4      HOBBIES_1_005_CA_1_validation  HOBBIES_1_005  HOBBIES_1  HOBBIES
# ...                              ...            ...        ...      ...
# 30485    FOODS_3_823_WI_3_validation    FOODS_3_823    FOODS_3    FOODS
# 30486    FOODS_3_824_WI_3_validation    FOODS_3_824    FOODS_3    FOODS
# 30487    FOODS_3_825_WI_3_validation    FOODS_3_825    FOODS_3    FOODS
# 30488    FOODS_3_826_WI_3_validation    FOODS_3_826    FOODS_3    FOODS
# 30489    FOODS_3_827_WI_3_validation    FOODS_3_827    FOODS_3    FOODS
#
#       store_id state_id  d_1  d_2  d_3  d_4  ...  d_1904  d_1905  d_1906  \
# ...

# %%
Cali =stv[stv.store_id == 'CA_1']

# %%
Wis =stv[stv.store_id == 'WI_1']

# %%
Tex =stv[stv.store_id == 'TX_1']

# %%
Wis = Wis.melt(id_vars=["id", "item_id", "dept_id", "cat_id", "store_id", "state_id"], 
        var_name="d", 
        value_name="Value")

# %%
Cali = Cali.melt(id_vars=["id", "item_id", "dept_id", "cat_id", "store_id", "state_id"], 
        var_name="d", 
        value_name="Value")

# %%
Tex = Tex.melt(id_vars=["id", "item_id", "dept_id", "cat_id", "store_id", "state_id"], 
        var_name="d", 
        value_name="Value")

# %%
Cali_sum = Cali.groupby(['item_id']).agg('sum').reset_index()

# %%
Wis_sum = Wis.groupby(['item_id']).agg('sum').reset_index()

# %%
Tex_sum = Tex.groupby(['item_id']).agg('sum').reset_index()

# %%
Top_10_Wis = Wis_sum.sort_values(by=['Value'], ascending=False).head(10)

# %%
Top_10_Wis
# Out:
#           item_id  Value
# 838   FOODS_3_226  78993
# 1306  FOODS_3_694  41228
# 702   FOODS_3_090  34852
# 1198  FOODS_3_586  32119
# 1325  FOODS_3_714  30980
# 1103  FOODS_3_491  26462
# 1280  FOODS_3_668  25533
# 655   FOODS_3_042  25010
# 692   FOODS_3_080  24765
# 83    FOODS_1_085  21174

# %%
Top_10_Tex = Tex_sum.sort_values(by=['Value'], ascending=False).head(10)

# %%
Top_10_Tex
# Out:
#           item_id   Value
# 1198  FOODS_3_586  112454
# 702   FOODS_3_090   93684
# 1167  FOODS_3_555   69516
# 864   FOODS_3_252   56294
# 1199  FOODS_3_587   48277
# 1325  FOODS_3_714   43567
# 814   FOODS_3_202   37940
# 1306  FOODS_3_694   36567
# 1334  FOODS_3_723   31907
# 1219  FOODS_3_607   28493

# %%
Top_10_Cali = Cali_sum.sort_values(by=['Value'], ascending=False).head(10)

# %%
Top_10_Cali
# Out:
#           item_id   Value
# 702   FOODS_3_090  127203
# 1198  FOODS_3_586   87691
# 864   FOODS_3_252   74971
# 732   FOODS_3_120   61899
# 1325  FOODS_3_714   54080
# 1199  FOODS_3_587   51717
# 1417  FOODS_3_808   46094
# 411   FOODS_2_197   40698
# 692   FOODS_3_080   39145
# 1167  FOODS_3_555   37871

# %%
df = pd.merge(cal, sellp, on='wm_yr_wk', how='inner')

# %%
df= df[df.item_id == 'FOODS_3_090']

# %%
Ca_1= df[df.store_id == 'CA_1']

# %%
Wi_1= df[df.store_id == 'WI_1']

# %%
Tx_1= df[df.store_id == 'TX_1']

# %%
Ca_1= Ca_1[:-56]

# %%
Wi_1= Wi_1[:-56]

# %%
Tx_1= Tx_1[:-56]

# %%
Tx_1
# Out:
#                 date  wm_yr_wk    weekday  wday  month  year       d  \
# 5351      2011-01-29     11101   Saturday     1      1  2011     d_1
# 16283     2011-01-30     11101     Sunday     2      1  2011     d_2
# 27215     2011-01-31     11101     Monday     3      1  2011     d_3
# 38147     2011-02-01     11101    Tuesday     4      2  2011     d_4
# 49079     2011-02-02     11101  Wednesday     5      2  2011     d_5
# ...              ...       ...        ...   ...    ...   ...     ...
# 45890017  2016-04-20     11612  Wednesday     5      4  2016  d_1909
# 45920507  2016-04-21     11612   Thursday     6      4  2016  d_1910
# 45950997  2016-04-22     11612     Friday     7      4  2016  d_1911
# 45981487  2016-04-23     11613   Saturday     1      4  2016  d_1912
# 46011977  2016-04-24     11613     Sunday     2      4  2016  d_1913
#
#          event_name_1 event_type_1 event_name_2 event_type_2  snap_CA  \
# ...

# %%
Cali_item = Cali[Cali.item_id == 'FOODS_3_090']

# %%
Cali_df = pd.merge(Cali_item, Ca_1, on = 'd', how='inner')

# %%
Cali_df
# Out:
#                                id    item_id_x  dept_id cat_id store_id_x  \
# 0     FOODS_3_090_CA_1_validation  FOODS_3_090  FOODS_3  FOODS       CA_1
# 1     FOODS_3_090_CA_1_validation  FOODS_3_090  FOODS_3  FOODS       CA_1
# 2     FOODS_3_090_CA_1_validation  FOODS_3_090  FOODS_3  FOODS       CA_1
# 3     FOODS_3_090_CA_1_validation  FOODS_3_090  FOODS_3  FOODS       CA_1
# 4     FOODS_3_090_CA_1_validation  FOODS_3_090  FOODS_3  FOODS       CA_1
# ...                           ...          ...      ...    ...        ...
# 1908  FOODS_3_090_CA_1_validation  FOODS_3_090  FOODS_3  FOODS       CA_1
# 1909  FOODS_3_090_CA_1_validation  FOODS_3_090  FOODS_3  FOODS       CA_1
# 1910  FOODS_3_090_CA_1_validation  FOODS_3_090  FOODS_3  FOODS       CA_1
# 1911  FOODS_3_090_CA_1_validation  FOODS_3_090  FOODS_3  FOODS       CA_1
# 1912  FOODS_3_090_CA_1_validation  FOODS_3_090  FOODS_3  FOODS       CA_1
#
#      state_id       d  Value        date  wm_yr_wk  ... event_name_1  \
# ...

# %%
Wis_item = Wis[Wis.item_id == 'FOODS_3_090']

# %%
Wis_df = pd.merge(Wis_item, Wi_1, on = 'd', how='inner')

# %%
Tex_item = Tex[Tex.item_id == 'FOODS_3_090']

# %%
Tex_df = pd.merge(Tex_item, Tx_1, on = 'd', how='inner')

# %%
Wis_df
# Out:
#                                id    item_id_x  dept_id cat_id store_id_x  \
# 0     FOODS_3_090_WI_1_validation  FOODS_3_090  FOODS_3  FOODS       WI_1
# 1     FOODS_3_090_WI_1_validation  FOODS_3_090  FOODS_3  FOODS       WI_1
# 2     FOODS_3_090_WI_1_validation  FOODS_3_090  FOODS_3  FOODS       WI_1
# 3     FOODS_3_090_WI_1_validation  FOODS_3_090  FOODS_3  FOODS       WI_1
# 4     FOODS_3_090_WI_1_validation  FOODS_3_090  FOODS_3  FOODS       WI_1
# ...                           ...          ...      ...    ...        ...
# 1908  FOODS_3_090_WI_1_validation  FOODS_3_090  FOODS_3  FOODS       WI_1
# 1909  FOODS_3_090_WI_1_validation  FOODS_3_090  FOODS_3  FOODS       WI_1
# 1910  FOODS_3_090_WI_1_validation  FOODS_3_090  FOODS_3  FOODS       WI_1
# 1911  FOODS_3_090_WI_1_validation  FOODS_3_090  FOODS_3  FOODS       WI_1
# 1912  FOODS_3_090_WI_1_validation  FOODS_3_090  FOODS_3  FOODS       WI_1
#
#      state_id       d  Value        date  wm_yr_wk  ... event_name_1  \
# ...

# %%
Tex_df
# Out:
#                                id    item_id_x  dept_id cat_id store_id_x  \
# 0     FOODS_3_090_TX_1_validation  FOODS_3_090  FOODS_3  FOODS       TX_1
# 1     FOODS_3_090_TX_1_validation  FOODS_3_090  FOODS_3  FOODS       TX_1
# 2     FOODS_3_090_TX_1_validation  FOODS_3_090  FOODS_3  FOODS       TX_1
# 3     FOODS_3_090_TX_1_validation  FOODS_3_090  FOODS_3  FOODS       TX_1
# 4     FOODS_3_090_TX_1_validation  FOODS_3_090  FOODS_3  FOODS       TX_1
# ...                           ...          ...      ...    ...        ...
# 1908  FOODS_3_090_TX_1_validation  FOODS_3_090  FOODS_3  FOODS       TX_1
# 1909  FOODS_3_090_TX_1_validation  FOODS_3_090  FOODS_3  FOODS       TX_1
# 1910  FOODS_3_090_TX_1_validation  FOODS_3_090  FOODS_3  FOODS       TX_1
# 1911  FOODS_3_090_TX_1_validation  FOODS_3_090  FOODS_3  FOODS       TX_1
# 1912  FOODS_3_090_TX_1_validation  FOODS_3_090  FOODS_3  FOODS       TX_1
#
#      state_id       d  Value        date  wm_yr_wk  ... event_name_1  \
# ...

# %%
Cali_df.to_excel ('Cali.xlsx', index = False, header=True)

# %%
Tex_df.to_excel ('Tex.xlsx', index = False, header=True)

# %%
Wis_df.to_excel ('Wis.xlsx', index = False, header=True)

# %%
Tex_df.corr()
# Out:
#                Value  wm_yr_wk      wday     month      year   snap_CA  \
# Value       1.000000 -0.006131 -0.112680  0.062104 -0.003297  0.012308
# wm_yr_wk   -0.006131  1.000000 -0.002379 -0.029676  0.988210 -0.002312
# wday       -0.112680 -0.002379  1.000000 -0.000771  0.001543  0.000360
# month       0.062104 -0.029676 -0.000771  1.000000 -0.163261 -0.004907
# year       -0.003297  0.988210  0.001543 -0.163261  1.000000  0.006004
# snap_CA     0.012308 -0.002312  0.000360 -0.004907  0.006004  1.000000
# snap_TX     0.016343 -0.000514  0.000360 -0.004907  0.006004  0.403585
# snap_WI     0.008757 -0.000307 -0.003532 -0.004907  0.006004  0.403585
# sell_price -0.190393  0.652722 -0.001374 -0.180675  0.664402 -0.001895
#
#              snap_TX   snap_WI  sell_price
# Value       0.016343  0.008757   -0.190393
# wm_yr_wk   -0.000514 -0.000307    0.652722
# wday        0.000360 -0.003532   -0.001374
# month      -0.004907 -0.004907   -0.180675
# ...

# %%
Cali_df.corr()
# Out:
#                Value  wm_yr_wk      wday     month      year   snap_CA  \
# Value       1.000000 -0.062090 -0.135628  0.201263 -0.082071  0.018186
# wm_yr_wk   -0.062090  1.000000 -0.002379 -0.029676  0.988210 -0.002312
# wday       -0.135628 -0.002379  1.000000 -0.000771  0.001543  0.000360
# month       0.201263 -0.029676 -0.000771  1.000000 -0.163261 -0.004907
# year       -0.082071  0.988210  0.001543 -0.163261  1.000000  0.006004
# snap_CA     0.018186 -0.002312  0.000360 -0.004907  0.006004  1.000000
# snap_TX     0.004976 -0.000514  0.000360 -0.004907  0.006004  0.403585
# snap_WI    -0.002600 -0.000307 -0.003532 -0.004907  0.006004  0.403585
# sell_price -0.225563  0.710704 -0.002255 -0.252922  0.729022 -0.008414
#
#              snap_TX   snap_WI  sell_price
# Value       0.004976 -0.002600   -0.225563
# wm_yr_wk   -0.000514 -0.000307    0.710704
# wday        0.000360 -0.003532   -0.002255
# month      -0.004907 -0.004907   -0.252922
# ...

# %%
Wis_df.corr()
# Out:
#                Value  wm_yr_wk      wday     month      year   snap_CA  \
# Value       1.000000  0.149938 -0.073560  0.128524  0.142508  0.010959
# wm_yr_wk    0.149938  1.000000 -0.002379 -0.029676  0.988210 -0.002312
# wday       -0.073560 -0.002379  1.000000 -0.000771  0.001543  0.000360
# month       0.128524 -0.029676 -0.000771  1.000000 -0.163261 -0.004907
# year        0.142508  0.988210  0.001543 -0.163261  1.000000  0.006004
# snap_CA     0.010959 -0.002312  0.000360 -0.004907  0.006004  1.000000
# snap_TX     0.028297 -0.000514  0.000360 -0.004907  0.006004  0.403585
# snap_WI     0.010772 -0.000307 -0.003532 -0.004907  0.006004  0.403585
# sell_price -0.115828  0.355319 -0.000567 -0.237711  0.374703  0.003752
#
#              snap_TX   snap_WI  sell_price
# Value       0.028297  0.010772   -0.115828
# wm_yr_wk   -0.000514 -0.000307    0.355319
# wday        0.000360 -0.003532   -0.000567
# month      -0.004907 -0.004907   -0.237711
# ...
